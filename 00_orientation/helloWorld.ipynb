# %%
print("Hello! World!")
print("こんにちは！ 世界！")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 budget = 100
#       2 price = 101
# ----> 3 assert  price < budget, f'手持ちが{budget}円しかないので、その電車には乗れません。'
#       4
#
# AssertionError: 手持ちが100円しかないので、その電車には乗れません。
